# %%
# Figure 1 (Single TOV solve plot)
import matplotlib.pyplot as plt
import numpy as np

# Set font to a more professional style
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 16,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 14,
    'text.latex.preamble': r'\usepackage{bm}',
})

# Data for plotting left
singletov = np.loadtxt("Singlestar_50icp.txt")

# Data for plotting right
multitov = np.loadtxt("FSUGarnet_RM.txt")
#multitov1 = np.loadtxt("gold_RM.txt")
J0030_68 = np.loadtxt("J0030_Riley19_NICERonly_STPST_68.txt")
J0030_95 = np.loadtxt("J0030_Riley19_NICERonly_STPST_95.txt")
J0740_68 = np.loadtxt("J0740_Riley21_68.txt")
J0740_95 = np.loadtxt("J0740_Riley21_95.txt")
J1231_68 = np.loadtxt("J1231_R21_contour_radius_mass_683.txt")
J1231_95 = np.loadtxt("J1231_R21_contour_radius_mass_954.txt")
J0437_68 = np.loadtxt("J0437_CST_PDT_3C50_BKG_AGN_smooth_3sigma_hiMN_lowXPSI_res_68.txt")
J0437_95 = np.loadtxt("J0437_CST_PDT_3C50_BKG_AGN_smooth_3sigma_hiMN_lowXPSI_res_95.txt")

# Create figure and subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].plot(2.95324203*singletov[:,3], singletov[:,4], label=r'FSUGarnet $\rho_c = 386.95 \, \rm MeV/fm^3$', color='maroon',lw=1.5)
ax[1].plot(multitov[:,3], multitov[:,4], label='FSUGarnet', color='maroon',lw=1.5)
#ax[1].plot(multitov1[:,3], multitov1[:,4], label='FSUGold2', color='darkgoldenrod',lw=1.5)
ax[1].plot(J0030_68[:,0], J0030_68[:,1], color='black',lw=1.5)
ax[1].plot(J0030_95[:,0], J0030_95[:,1], color='black',lw=1.5)
ax[1].plot(J0740_68[:,0], J0740_68[:,1], color='black',lw=1.5)
ax[1].plot(J0740_95[:,0], J0740_95[:,1], color='black',lw=1.5)
ax[1].plot(J1231_68[:,0], J1231_68[:,1], color='black',lw=1.5)
ax[1].plot(J1231_95[:,0], J1231_95[:,1], color='black',lw=1.5)
ax[1].plot(J0437_68[:,0], J0437_68[:,1], color='black',lw=1.5)
ax[1].plot(J0437_95[:,0], J0437_95[:,1], color='black',lw=1.5)
    
# Customization for left plot
ax[0].set_xlabel(r'$ \rm r (\rm km)$',fontweight='bold')
ax[0].set_ylabel(r'$(M/M_{\odot})$',fontweight='bold')

# Customization for right plot
ax[1].set_xlabel(r'$ \rm Radius (\rm km)$',fontweight='bold')
ax[1].set_ylabel(r'$(M/M_{\odot})$',fontweight='bold')
ax[1].fill(J0030_68[:,0],J0030_68[:,1], color='indianred', alpha=0.5)
ax[1].fill(J0030_95[:,0],J0030_95[:,1], color='lightcoral', alpha=0.2)
ax[1].fill(J0740_68[:,0],J0740_68[:,1], color='olivedrab', alpha=0.5)
ax[1].fill(J0740_95[:,0],J0740_95[:,1], color='yellowgreen', alpha=0.2)
ax[1].fill(J1231_68[:,0],J1231_68[:,1], color='darkslategrey', alpha=0.5)
ax[1].fill(J1231_95[:,0],J1231_95[:,1], color='teal', alpha=0.2)
ax[1].fill(J0437_68[:,0],J0437_68[:,1], color='rebeccapurple', alpha=0.5)
ax[1].fill(J0437_95[:,0],J0437_95[:,1], color='blueviolet', alpha=0.2)
ax[1].text(15.5,1.55,'J0030+0451',fontsize=13)
ax[1].text(15.8,2.07,'J0740+6620',fontsize=13)
ax[1].text(10.2,1.55,'J0437-4715',fontsize=13)
ax[1].text(13.7,1.0,'J1231-1411',fontsize=13)

# Adjust layout
plt.tight_layout()

# Save the figure (optional)
plt.savefig('Figure1.png', dpi=500)

# %%
# Figure 1 (Single TOV solve plot)
import matplotlib.pyplot as plt
import numpy as np

# Set font to a more professional style
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 16,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 14,
    'text.latex.preamble': r'\usepackage{bm}',
})

# Data for plotting left
Baym = np.loadtxt("FSUGarnet_Baym_RM.txt")
Stand = np.loadtxt("FSUGarnet_RM.txt")
NC = np.loadtxt("FSUGarnet_NC_RM.txt")

# Data for plotting right
Baym = np.loadtxt("FSUGarnet_Baym_RM.txt")
Stand = np.loadtxt("FSUGarnet_RM.txt")
BSk25 = np.loadtxt("FSUGarnet_BSk_RM.txt")
J0030_68 = np.loadtxt("J0030_Riley19_NICERonly_STPST_68.txt")
J0030_95 = np.loadtxt("J0030_Riley19_NICERonly_STPST_95.txt")
J0740_68 = np.loadtxt("J0740_Riley21_68.txt")
J0740_95 = np.loadtxt("J0740_Riley21_95.txt")

# Create figure and subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].plot(Stand[:,3], Stand[:,4], label=r'FSUGarnet + Crust', color='maroon',lw=1.5)
ax[0].plot(NC[:,3], NC[:,4], label=r'FSUGarnet w/o Crust', color='maroon',ls='dashed',lw=1.5)

ax[1].plot(Stand[:,3], Stand[:,4], label=r'FSUGarnet A', color='maroon',lw=1.5)
ax[1].plot(Baym[:,3], Baym[:,4], label=r'FSUGarnet B', color='maroon',ls='dashed',lw=1.5)
ax[1].plot(BSk25[:,3], BSk25[:,4], label=r'FSUGarnet C', color='maroon',ls='dotted',lw=1.5)

# Adjust layout
plt.tight_layout()
ax[0].legend()
ax[1].legend()

# Save the figure (optional)
plt.savefig('Figure3.png', dpi=500)

# %%
# Figure 4 (Single TOV solve plot)
import matplotlib.pyplot as plt
import numpy as np

# Set font to a more professional style
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 16,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 14,
    'text.latex.preamble': r'\usepackage{bm}',
})

# Data for plotting left
garnet = np.loadtxt("FSUGarnet_Core_EOS.txt")
gold = np.loadtxt("FSUGold2_Core_EOS.txt")

# Data for plotting right
gold_comp = np.loadtxt("FSUGold2_comp.txt")
garnet_comp = np.loadtxt("FSUGarnet_comp.txt")


# Create figure and subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].plot(gold[:,0], gold[:,2], color='black',lw=1.5,label='FSUGold2')
ax[0].plot(garnet[:,0], garnet[:,2], color='maroon',lw=1.5,label='FSUGarnet')

ax[1].plot(gold[:,0], gold_comp[:,0], color='black',lw=1.5)
ax[1].plot(gold[:,0], gold_comp[:,1], color='black',lw=1.5, ls='dashed')
ax[1].plot(gold[:,0], gold_comp[:,2], color='black',lw=1.5, ls='dotted')
ax[1].plot(gold[:,0], gold_comp[:,3], color='black',lw=1.5, ls='-.')

ax[1].plot(garnet[:,0], garnet_comp[:,0], color='maroon',lw=1.5,label='n')
ax[1].plot(garnet[:,0], garnet_comp[:,1], color='maroon',lw=1.5,ls='dashed',label='p')
ax[1].plot(garnet[:,0], garnet_comp[:,2], color='maroon',lw=1.5,ls='dotted',label=r'$e^-$')
ax[1].plot(garnet[:,0], garnet_comp[:,3], color='maroon',lw=1.5,ls='-.',label=r'$\mu^-$')

    
# Customization for left plot
ax[0].set_xlabel(r'$\rho \,\,(\textrm{fm}^{-3})$',fontweight='bold')
ax[0].set_ylabel(r'$P \,\, (\textrm{MeV}/\textrm{fm}^{3})$',fontweight='bold')
ax[0].set_yscale('log')
ax[0].legend(loc='lower right')

# Customization for right plot
ax[1].set_xlabel(r'$\rho \,\, (\textrm{fm}^{-3})$',fontweight='bold')
ax[1].set_ylabel('Relative Population',fontweight='bold')
ax[1].set_yscale('log')
ax[1].legend(loc='lower right')

# Adjust layout
plt.tight_layout()

# Save the figure (optional)
plt.savefig('Figure4.png', dpi=500)

# %%
# Figure 5 (Single TOV solve plot)
import matplotlib.pyplot as plt
import numpy as np

# Set font to a more professional style
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 16,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 14,
    'text.latex.preamble': r'\usepackage{bm}',
})

# Data for plotting left
garnetCa = np.loadtxt("densities48,20_gar.txt")
goldCa = np.loadtxt("densities48,20_gold.txt")
expCa = np.loadtxt("FBDens48Ca.txt")

# Data for plotting right
garnetPb = np.loadtxt("densities208,82_gar.txt")
goldPb = np.loadtxt("densities208,82_gold.txt")
expPb = np.loadtxt("FBDens208Pb.txt")


# Create figure and subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].plot(garnetCa[:,0], garnetCa[:,7], color='maroon',lw=1.5,label='FSUGarnet')
ax[0].plot(goldCa[:,0], goldCa[:,7], color='navy',lw=1.5,label='FSUGold2')
ax[0].plot(expCa[:,0], expCa[:,1], color='black',lw=1.5,label='Exp',ls='dashed')

ax[1].plot(garnetPb[:,0], garnetPb[:,7], color='maroon',lw=1.5,label='FSUGarnet')
ax[1].plot(goldPb[:,0], goldPb[:,7], color='navy',lw=1.5,label='FSUGold2')
ax[1].plot(expPb[:,0], expPb[:,1], color='black',lw=1.5,label='Exp',ls='dashed')

    
# Customization for left plot
ax[0].set_xlabel('r (fm)',fontweight='bold')
ax[0].set_ylabel(r'$\rho_\textrm{ch} \, \, (\textrm{fm}^{-3})$',fontweight='bold')
ax[0].legend(loc='lower left')
ax[0].set_xlim(0,7)
ax[0].text(5.5,0.08,r'$^{48}$\textrm{Ca}',fontsize=16)

# Customization for right plot
ax[1].set_xlabel('r (fm)',fontweight='bold')
ax[1].set_ylabel(r'$\rho_\textrm{ch} \, \, (\textrm{fm}^{-3})$',fontweight='bold')
ax[1].set_xlim(0,10)
ax[1].text(7.5,0.0625,r'$^{208}$\textrm{Pb}',fontsize=16)

# Adjust layout
plt.tight_layout()

# Save the figure (optional)
plt.savefig('Figure5.png', dpi=500)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})
import numpy as np
plt.rc('axes', unicode_minus=False)

chargeffCa48_gar = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48,gar.txt")
chargeffCa48_gold = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48,gold.txt")
chargeffCa48_garR = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_garR.txt")
chargeffCa48_goldR = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_goldR.txt")
chargeffPb_gar = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb208,gar.txt")
chargeffPb_gold = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb208,gold.txt")
chargeffPb_garR = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb208_garR.txt")
chargeffPb_goldR = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb208_goldR.txt")

# Adjust start and end of EOS data
l = 300
m = 300

fig, axs = plt.subplots(1, 2,figsize=(15,6),sharey=False, sharex=False, facecolor='white')

q = chargeffCa48_gold[:m,0]/1.25
exp = chargeffCa48_gold[:m,3]
axs[0].plot(q, exp, color='darkgoldenrod',ls='solid',lw=3)

q = chargeffCa48_gar[:m,0]/1.25
exp = chargeffCa48_gar[:m,3]
axs[0].plot(q, exp, color='maroon',ls='solid',lw=3)

q = chargeffCa48_goldR[:m,0]/1.25
exp = chargeffCa48_goldR[:m,3]
axs[0].plot(q, exp, color='darkgoldenrod',ls='dashed',lw=3)

q = chargeffCa48_garR[:m,0]/1.25
exp = chargeffCa48_garR[:m,3]
axs[0].plot(q, exp, color='maroon',ls='dashed',lw=3)


q = chargeffPb_gold[:m,0]/1.25
exp = chargeffPb_gold[:m,3]
axs[1].plot(q, exp, color='darkgoldenrod',ls='solid',lw=3)

q = chargeffPb_gar[:m,0]/1.25
exp = chargeffPb_gar[:m,3]
axs[1].plot(q, exp, color='maroon',ls='solid',lw=3)

q = chargeffPb_goldR[:m,0]/1.25
exp = chargeffPb_goldR[:m,3]
axs[1].plot(q, exp, color='darkgoldenrod',ls='dashed',lw=3)

q = chargeffPb_garR[:m,0]/1.25
exp = chargeffPb_garR[:m,3]
axs[1].plot(q, exp, color='maroon',ls='dashed',lw=3)

axs[0].errorbar(0.8733,0.0277,yerr=[[0.0055],[0.0055]],capsize=5, color='black')
axs[1].errorbar(0.3977,0.041,yerr=[[0.013],[0.013]],capsize=5, color='black')
axs[0].plot(0.8733,0.0277,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=8) #crex
axs[1].plot(0.3977,0.041,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=8) #prex

axs[1].set_ylabel(r'$\rm F_{ch} - F_{wk}$ ($^{208}$Pb)',size=20)
axs[0].set_ylabel(r'$\rm F_{ch} - F_{wk}$ ($^{48}$Ca)',size=20)

axs[1].set_xlabel(r'q (fm$^{-1})$',size=20)
axs[0].set_xlabel(r'q (fm$^{-1})$',size=20)

plt.legend(['FSUGold2','FSUGarnet','FSUGold2+R','FSUGarnet+R'],fontsize=18,loc='upper right')
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.tight_layout()

plt.savefig('Figure14',dpi=500)

# %%
import numpy as np
import matplotlib
from matplotlib.patches import Ellipse
import matplotlib.pyplot as plt
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 25,
    'xtick.labelsize': 25,
    'ytick.labelsize': 25,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

def eigsorted(cov):
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    return vals[order], vecs[:,order]

# Define the mean and covariance matrix for the bivariate Gaussian
mean = [0.041, 0.0277]  # Mean values for x and y
covariance_matrix = [[0.013**2, 0], [0, 0.0055**2]]  # Covariance matrix

# Number of data points
num_points = 10000

# Generate x and y values from the bivariate Gaussian distribution
x, y = np.random.multivariate_normal(mean, covariance_matrix, num_points).T

fig, ax = plt.subplots(1, 2,figsize=(18,8),sharey=False, sharex=False, facecolor='white')
# plot the contours
nstd = 1.489
cov = np.cov(x, y)
vals, vecs = eigsorted(cov)
theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
w, h = 2 * nstd * np.sqrt(vals)
ell = Ellipse(xy=(np.mean(x), np.mean(y)),
              width=w, height=h,
              angle=theta, color='black')
ell.set_facecolor('none')
ax[0].add_artist(ell)

nstd = 2.4475
cov = np.cov(x, y)
vals, vecs = eigsorted(cov)
theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
w, h = 2 * nstd * np.sqrt(vals)
ell = Ellipse(xy=(np.mean(x), np.mean(y)),
              width=w, height=h,
              angle=theta, color='black')
ell.set_facecolor('none')
ax[0].add_artist(ell)
#####################################

ax[0].scatter(x, y, alpha=0.00)

# Set the x-axis and y-axis limits
ax[0].set_xlim(0, 0.075)  # Set x-axis limits from 0 to 6
ax[0].set_ylim(0.01, 0.06)  # Set y-axis limits from 0 to 6

# FSUGarnet, Gold2, IUFSU, BigApple
# FSUGold2_L47, FSUGold2_L50, FSUGold2_L54, FSUGold2_L58, FSUGold2_L69, FSUGold2_L76, FSUGold2_L90, FSUGold2_L100, RMF022, RMF028, RMF032
# TAMUa, OMEG1, OMEG2
fch_fwk_Pb208 = np.array([0.02297,0.0422,0.0233,0.0215,
                    0.0216,0.0242,0.0269,0.0290,0.0333,0.0353,0.0385,0.0403,0.0315,0.0421,0.0467,
                    0.0366,0.0359,0.0303,0.0200])

fch_fwk_Ca48 = np.array([0.0437,0.0565,0.0439,0.0417,
                    0.0422,0.0442,0.0462,0.0477,0.0507,0.0520,0.0541,0.0553,0.0494,0.0566,0.0583,
                    0.0527,0.05079,0.0472,0.0400])

# Other models
ax[0].plot(fch_fwk_Pb208,fch_fwk_Ca48,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=11,linestyle='None')
ax[0].plot(0.02297,0.0437,marker='s',markerfacecolor='maroon',markeredgecolor='maroon',markersize=11) #FSUGarnet
ax[0].plot(0.0422,0.0565,marker='s',markerfacecolor='darkgoldenrod',markeredgecolor='darkgoldenrod',markersize=11) #FSUGold2

# DINO
ax[0].plot(0.0265,0.0336,marker='*',markerfacecolor='blue',markeredgecolor='black',markersize=23) #FSUtd-1
ax[0].plot(0.0303,0.0349,marker='*',markerfacecolor='red',markeredgecolor='black',markersize=23) #FSUtd-2
ax[0].plot(0.0344,0.0367,marker='*',markerfacecolor='green',markeredgecolor='black',markersize=23) #FSUtd-3

#ax[0].plot(0.0235,0.0336,marker='*',markerfacecolor='darkgoldenrod',markeredgecolor='black',markersize=18) #exp

dinoa = np.loadtxt("densities208,82_dinoa.txt")
dinob = np.loadtxt("densities208,82_dinob.txt")
dinoc = np.loadtxt("densities208,82_dinoc.txt")
exp = np.loadtxt("FBDens208Pb.txt")

ax[1].plot(dinoa[:,0],dinoa[:,7],color='blue',lw=3)
ax[1].plot(dinob[:,0],dinob[:,7],color='red',lw=3)
ax[1].plot(dinoc[:,0],dinoc[:,7],color='green',lw=3)
ax[1].plot(exp[:,0], exp[:,1],color='black',lw=3)

ax[0].set_xlabel(r'${\rm F}_{\rm ch} - {\rm F}_{\rm wk}$ ($^{208}$Pb)',size=25)
ax[0].set_ylabel(r'${\rm F}_{\rm ch} - {\rm F}_{\rm wk}$ ($^{48}$Ca)',size=25)

ax[1].set_xlabel('r (fm)',size=25)
ax[1].set_ylabel(r'$\rho_{\rm{ch}}$ (fm$^{-3}$)',size=25)

# Set the x-axis and y-axis limits
ax[1].set_xlim(0, 10)  # Set x-axis limits from 0 to 6

ax[0].text(0.024,0.024,'67\%',fontsize=20)
ax[0].text(0.014,0.021,'95\%',fontsize=20)
ax[0].text(0.008,0.045,'FSUGarnet',fontsize=22)
ax[0].text(0.027,0.057,'FSUGold2',fontsize=22)

plt.legend([r'DINOa',r'DINOb',r'DINOc','Exp'],fontsize=22,loc='upper right')

plt.tight_layout()
plt.savefig('Figure16',dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

densityCa48_dinoa = np.loadtxt("densities48,20_dinoa.txt")
densityPb_dinoa = np.loadtxt("densities208,82_dinoa.txt")

densityCa48_fp_p = np.loadtxt("densities48,20_fp_p10.txt")
densityPb_fp_p = np.loadtxt("densities208,82_fp_p10.txt")
densityCa48_fp_n = np.loadtxt("densities48,20_fp_n4.txt")
densityPb_fp_n = np.loadtxt("densities208,82_fp_n4.txt")

densityCa48_exp = np.loadtxt("FBDens48Ca.txt")
densityPb_exp = np.loadtxt("FBDens208Pb.txt")

fig, axs = plt.subplots(1, 1,figsize=(8,6),sharey=False, sharex=False, facecolor='white')
end1 = 600
end2 = 450
endex1 = 200
endex2 = 200
 ##########################################
r = densityCa48_exp[:endex1,0]
exp = densityCa48_exp[:endex1,1]
axs.scatter(r, exp, color='firebrick', marker='o',facecolors='none',s=50)

r = densityCa48_dinoa[:end1,0]
the = densityCa48_dinoa[:end1,7]
axs.plot(r, the, color='firebrick',ls='solid',lw=3)

r = densityCa48_fp_p[:end1,0]
the = densityCa48_fp_p[:end1,7]
axs.plot(r, the, color='firebrick',ls='dashed',lw=3)

r = densityCa48_fp_n[:end1,0]
the = densityCa48_fp_n[:end1,7]
axs.plot(r, the, color='firebrick',ls='-.',lw=3)
################################################
r = densityPb_exp[:endex2,0]
exp = densityPb_exp[:endex2,1]
axs.scatter(r, exp, color='green', marker='o',facecolors='none',s=50)

r = densityPb_dinoa[:end2,0]
the = densityPb_dinoa[:end2,7]
axs.plot(r, the, color='green',ls='solid',lw=3)

r = densityPb_fp_p[:end2,0]
the = densityPb_fp_p[:end2,7]
axs.plot(r, the, color='green',ls='dashed',lw=3)

r = densityPb_fp_n[:end2,0]
the = densityPb_fp_n[:end2,7]
axs.plot(r, the, color='green',ls='-.',lw=3)

plt.xlabel("r (fm)",size=20)
axs.set_ylabel(r"Charge Density (${\rm fm}^{-3}$) ",size=20)

leg = axs.legend(["Exp","DINOa",r"$\delta$ + ($f_\rho>$0)",r"$\delta$ + ($f_\rho<$0)"],fontsize=18)
for handle in leg.legendHandles:
    handle.set_color('black')

axs.set_xlim(0.0, 10)  # Set x-axis limits from 0 to 6
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
plt.savefig('Figure17',dpi=500)
# Out:
# /var/folders/c7/z26l7xyn1cnb0595y6v37x8c0000gn/T/ipykernel_98113/33615068.py:69: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in leg.legendHandles:

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

densityCa48_dinoa = np.loadtxt("densities48,20_dinoa.txt")
densityPb_dinoa = np.loadtxt("densities208,82_dinoa.txt")

densityCa48_fw0 = np.loadtxt("densities48,20_tensor,fw0.txt")
densityPb_fw0 = np.loadtxt("densities208,82_tensor,fw0.txt")

densityCa48_tensor = np.loadtxt("densities48,20,delta_tensor.txt")
densityPb_tensor = np.loadtxt("densities208,82,delta_tensor.txt")

densityCa48_exp = np.loadtxt("FBDens48Ca.txt")
densityPb_exp = np.loadtxt("FBDens208Pb.txt")

fig, axs = plt.subplots(1, 1,figsize=(8,6),sharey=False, sharex=False, facecolor='white')
end1 = 600
end2 = 450
endex1 = 200
endex2 = 200
 ##########################################
r = densityCa48_exp[:endex1,0]
exp = densityCa48_exp[:endex1,1]
axs.scatter(r, exp, color='firebrick', marker='o',facecolors='none',s=50)

r = densityCa48_dinoa[:end1,0]
the = densityCa48_dinoa[:end1,7]
axs.plot(r, the, color='firebrick',ls='solid',lw=3)

r = densityCa48_tensor[:end1,0]
the = densityCa48_tensor[:end1,7]
axs.plot(r, the, color='firebrick',ls='dashed',lw=3)

r = densityCa48_fw0[:end1,0]
the = densityCa48_fw0[:end1,7]
axs.plot(r, the, color='firebrick',ls='-.',lw=3)
################################################
r = densityPb_exp[:endex2,0]
exp = densityPb_exp[:endex2,1]
axs.scatter(r, exp, color='green', marker='o',facecolors='none',s=50)

r = densityPb_dinoa[:end2,0]
the = densityPb_dinoa[:end2,7]
axs.plot(r, the, color='green',ls='solid',lw=3)

r = densityPb_tensor[:end2,0]
the = densityPb_tensor[:end2,7]
axs.plot(r, the, color='green',ls='dashed',lw=3)

r = densityPb_fw0[:end2,0]
the = densityPb_fw0[:end2,7]
axs.plot(r, the, color='green',ls='-.',lw=3)

plt.xlabel("r (fm)",size=20)
axs.set_ylabel(r"Charge Density (${\rm fm}^{-3}$) ",size=20)

leg = axs.legend(["Exp","DINOa",r"$\delta$ + $f_\rho$ + $f_{\rm v}$",r"$\delta$ + $f_\rho$"],fontsize=20)
for handle in leg.legendHandles:
    handle.set_color('black')

axs.set_xlim(0.0, 10)  # Set x-axis limits from 0 to 6
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
plt.savefig('Figure18',dpi=500)
# Out:
# /var/folders/c7/z26l7xyn1cnb0595y6v37x8c0000gn/T/ipykernel_98113/3632505301.py:70: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in leg.legendHandles:

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

# import MR data
dinoa_RM = np.loadtxt("DINOa_RM.txt")
plambda = np.loadtxt("DINOa+scalar_RM.txt")
nlambda = np.loadtxt("DINOa-scalar_RM.txt")


# Generate 67 and 95 percent contours
##############################################
def eigsorted(cov):
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    return vals[order], vecs[:,order]

# Define the mean and covariance matrix for the bivariate Gaussian
mean = [0.041, 0.0277]  # Mean values for x and y
covariance_matrix = [[0.013**2, 0], [0, 0.0055**2]]  # Covariance matrix

# Number of data points
num_points = 10000

# Generate x and y values from the bivariate Gaussian distribution
x, y = np.random.multivariate_normal(mean, covariance_matrix, num_points).T

# plot XEFT data and FSU PNM EOS
fig, ax1 = plt.subplots(1,1,figsize=(8,8))
# Plot MR curves
ax1.plot(dinoa_RM[:,3],dinoa_RM[:,4],color='black',lw=3)
ax1.plot(plambda[:,3],plambda[:,4],color='green',lw=3)
ax1.plot(nlambda[:,3],nlambda[:,4],color='red',lw=3)

ax1.set(xlabel='Radius (km)',ylabel=r'Mass ($\rm M/M_{\odot}$)')

ax1.legend([r'DINOa $(\Lambda_{1.4} = 1326.1)$',r"DINOa + $\Lambda_s$  $(\Lambda_{1.4} = 1191.7$)",r"DINOa - $\Lambda_s$  $(\Lambda_{1.4} = 1511.9$)"],loc=[0.41,0.19],fontsize=18)
ax1.set_ylim([0,2.3])
ax1.set_xlim([12,19])

left, bottom, width, height = [0.56, 0.57, 0.35, 0.35]
ax2 = fig.add_axes([left, bottom, width, height])

# plot the contours
#sqrt[-2*ln(1-p)]
nstd = 1.489
cov = np.cov(x, y)
vals, vecs = eigsorted(cov)
theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
w, h = 2 * nstd * np.sqrt(vals)
ell = Ellipse(xy=(np.mean(x), np.mean(y)),
              width=w, height=h,
              angle=theta, color='black',lw=2)
ell.set_facecolor('none')
ax2.add_artist(ell)

nstd = 2.4475
cov = np.cov(x, y)
vals, vecs = eigsorted(cov)
theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
w, h = 2 * nstd * np.sqrt(vals)
ell = Ellipse(xy=(np.mean(x), np.mean(y)),
              width=w, height=h,
              angle=theta, color='black',lw=2)
ell.set_facecolor('none')
ax2.add_artist(ell)

# Plot DINO models weak skin
ax2.plot(0.0263,0.0333,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=10,lw=3) #DINO a
ax2.plot(0.0303,0.0349,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=10,lw=3) #DINO b
ax2.plot(0.0344,0.0367,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=10,lw=3) #DINO c

# Plot DINO + lambda_s weak skin
ax2.plot(0.02929,0.0300,marker='d',markerfacecolor='red',markeredgecolor='black',markersize=14,lw=3) #DINO a - lambda_s (-0.00025)
ax2.plot(0.02585,0.03469,marker='d',markerfacecolor='green',markeredgecolor='black',markersize=14,lw=3) #DINO a + lambda_s (0.00025)

# Set the x-axis and y-axis limits for weak skin
ax2.set_xlim(0.02, 0.04)  # Set x-axis limits from 0 to 6
ax2.set_ylim(0.02, 0.05)  # Set y-axis limits from 0 to 6
ax2.set(xlabel=r'${\rm F}_{\rm ch} - {\rm F}_{\rm wk}$ ($^{208}$Pb)',ylabel=r'${\rm F}_{\rm ch} - {\rm F}_{\rm wk}$ ($^{48}$Ca)')
ax2.annotate(r'67\%', xy=(0.022, 0.033), xytext=(0.022, 0.033),color='black',size=16)
ax2.annotate(r'95\%', xy=(0.022, 0.040), xytext=(0.022, 0.040),color='black',size=16)
#ax2.text(0.024,0.024,'67%',fontsize=15)
#ax2.text(0.014,0.021,'95%',fontsize=15)

plt.rc('axes', labelsize=25)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
ax2.tick_params(axis='both', which='both', labelsize=16)
ax2.xaxis.label.set_size(20)  # Adjust x-axis label size
ax2.yaxis.label.set_size(20)  # Adjust y-axis label size

plt.tight_layout()
plt.savefig('Figure19.png',transparent=False,facecolor='white',dpi=500)
# Out:
# /var/folders/c7/z26l7xyn1cnb0595y6v37x8c0000gn/T/ipykernel_98113/532030828.py:106: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

densityCa48_FSUtd1 = np.loadtxt("densities48,20,FSUTDa.txt")
densityPb_FSUtd1 = np.loadtxt("densities208,82,FSUTDa.txt")
densityCa48_FSUtd2 = np.loadtxt("densities48,20,FSUTDb.txt")
densityPb_FSUtd2 = np.loadtxt("densities208,82,FSUTDb.txt")
densityCa48_FSUtd3 = np.loadtxt("densities48,20,FSUT.txt")
densityPb_FSUtd3 = np.loadtxt("densities208,82,FSUT.txt")

densityCa48_test = np.loadtxt("densities48,20.txt")
densityPb_test = np.loadtxt("densities208,82.txt")

densityCa48_gar = np.loadtxt("densities48,20_gar.txt")
densityPb_gar = np.loadtxt("densities208,82_gar.txt")

densityCa48_exp = np.loadtxt("FBDens48Ca.txt")
densityPb_exp = np.loadtxt("FBDens208Pb.txt")

fig, axs = plt.subplots(1, 2,figsize=(23,10),sharey=False, sharex=False, facecolor='white')
end1 = 440
end2 = 390
endex1 = 120
endex2 = 200
 ##########################################
r = densityCa48_exp[:endex1,0]
exp = densityCa48_exp[:endex1,1]
axs[0].scatter(r, exp, color='black', marker='o',facecolors='none',s=70)

r = densityCa48_FSUtd3[:end1,0]
the = densityCa48_FSUtd3[:end1,7]
axs[0].plot(r, the, color='green',ls='solid',lw=3)

r = densityCa48_FSUtd1[:end1,0]
the = densityCa48_FSUtd1[:end1,7]
axs[0].plot(r, the, color='blue',ls='solid',lw=3)

r = densityCa48_FSUtd2[:end1,0]
the = densityCa48_FSUtd2[:end1,7]
axs[0].plot(r, the, color='red',ls='solid',lw=3)

r = densityCa48_gar[:end1,0]
the = densityCa48_gar[:end1,7]
axs[0].plot(r, the, color='maroon',ls='solid',lw=3)

r = densityCa48_test[:150,0]
the = densityCa48_test[:150,7]
axs[0].plot(r, the, color='orange',ls='solid',lw=3)

################################################
r = densityPb_exp[:endex2,0]
exp = densityPb_exp[:endex2,1]
axs[1].scatter(r, exp, color='black', marker='o',facecolors='none',s=70)

r = densityPb_FSUtd3[:end2,0]
the = densityPb_FSUtd3[:end2,7]
axs[1].plot(r, the, color='green',ls='solid',lw=3)

r = densityPb_FSUtd1[:end2,0]
the = densityPb_FSUtd1[:end2,7]
axs[1].plot(r, the, color='blue',ls='solid',lw=3)

r = densityPb_FSUtd2[:end2,0]
the = densityPb_FSUtd2[:end2,7]
axs[1].plot(r, the, color='red',ls='solid',lw=3)

r = densityPb_gar[:end2,0]
the = densityPb_gar[:end2,7]
axs[1].plot(r, the, color='maroon',ls='solid',lw=3)

r = densityPb_test[:150,0]
the = densityPb_test[:150,7]
axs[1].plot(r, the, color='orange',ls='solid',lw=3)

axs[0].set_xlabel("r (fm)",size=30)
axs[1].set_xlabel("r (fm)",size=30)
axs[0].set_ylabel(r'$^{48}$Ca Charge Density (fm$^{-3}$)',size=30)
axs[1].set_ylabel(r'$^{208}$Pb Charge Density (fm$^{-3}$)',size=30)

chargeffCa48_FSUTDa = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_FSUTDa.txt")
chargeffCa48_FSUTDb = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_FSUTDb.txt")
chargeffCa48_FSUT = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_FSUT.txt")
chargeffPb_FSUTDa = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb_FSUTDa.txt")
chargeffPb_FSUTDb = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb_FSUTDb.txt")
chargeffPb_FSUT = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb_FSUT.txt")

chargeffCa48_exp = np.loadtxt("FBFoFa48Ca.txt")
chargeffPb_exp = np.loadtxt("FBFoFa208Pb.txt")


left, bottom, width, height = [0.115, 0.205, 0.18, 0.40]
ax2 = fig.add_axes([left, bottom, width, height])

left, bottom, width, height = [0.61, 0.21, 0.18, 0.40]
ax3 = fig.add_axes([left, bottom, width, height])

q = chargeffCa48_FSUT[:,0]/1.25
exp = chargeffCa48_FSUT[:,1]**2
ax2.plot(q, exp, color='green',ls='solid',lw=3)

q = chargeffCa48_FSUTDa[:,0]/1.25
exp = chargeffCa48_FSUTDa[:,1]**2
ax2.plot(q, exp, color='blue',ls='solid',lw=3)

q = chargeffCa48_FSUTDb[:,0]/1.25
exp = chargeffCa48_FSUTDb[:,1]**2
ax2.plot(q, exp, color='red',ls='solid',lw=3)

q = chargeffCa48_exp[:,0]
exp = chargeffCa48_exp[:,1]**2
ax2.scatter(q, exp, color='black', marker='o',facecolors='none',s=70)

q = chargeffPb_FSUT[:,0]/1.25
exp = chargeffPb_FSUT[:,1]**2
ax3.plot(q, exp, color='green',ls='solid',lw=3)

q = chargeffPb_FSUTDa[:,0]/1.25
exp = chargeffPb_FSUTDa[:,1]**2
ax3.plot(q, exp, color='blue',ls='solid',lw=3)

q = chargeffPb_FSUTDb[:,0]/1.25
exp = chargeffPb_FSUTDb[:,1]**2
ax3.plot(q, exp, color='red',ls='solid',lw=3)

q = chargeffPb_exp[:,0]
exp = chargeffPb_exp[:,1]**2
ax3.scatter(q, exp, color='black', marker='o',facecolors='none',s=70)

ax2.set_xlim(0.0, 4.0)  # Set x-axis limits from 0 to 6
ax2.set_ylim(10e-10, 10)  # Set y-axis limits from 0 to 6

ax3.set_xlim(0.0, 3.5)  # Set x-axis limits from 0 to 6
ax3.set_ylim(10e-10, 10)  # Set y-axis limits from 0 to 6

ax2.set(xlabel=r'q (${\rm fm}^{-1})$',ylabel=r'$\bf{|{\rm F}_{\rm ch}|^2}$')
ax3.set(xlabel=r'q (${\rm fm}^{-1})$',ylabel=r'$\bf{|{\rm F}_{\rm ch}|^2}$')

ax2.set_yscale('log')
ax3.set_yscale('log')

axs[0].legend(["Exp","FSU-TD0",'FSU-TD1','FSU-TD2','FSUGarnet'],fontsize=25)
plt.rc('axes', labelsize=33)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=33)    # fontsize of the tick labels
plt.rc('ytick', labelsize=33)    # fontsize of the tick labels
ax2.tick_params(axis='both', which='both', labelsize=24)
ax3.tick_params(axis='both', which='both', labelsize=24)
ax2.xaxis.label.set_size(25)  # Adjust x-axis label size
ax2.yaxis.label.set_size(25)  # Adjust y-axis label size
ax3.xaxis.label.set_size(25)  # Adjust x-axis label size
ax3.yaxis.label.set_size(25)  # Adjust y-axis label size
plt.tight_layout()
#plt.savefig('Figure20',dpi=500)
# Out:
# /var/folders/c7/z26l7xyn1cnb0595y6v37x8c0000gn/T/ipykernel_45582/2124181173.py:163: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 25,
    'xtick.labelsize': 26,
    'ytick.labelsize': 26,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

def eigsorted(cov):
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    return vals[order], vecs[:,order]

# Define the mean and covariance matrix for the bivariate Gaussian
mean = [0.041, 0.0277]  # Mean values for x and y
covariance_matrix = [[0.013**2, 0], [0, 0.0055**2]]  # Covariance matrix

# Number of data points
num_points = 10000

# Generate x and y values from the bivariate Gaussian distribution
x, y = np.random.multivariate_normal(mean, covariance_matrix, num_points).T

fig, ax = plt.subplots(1, 2,figsize=(18,8),sharey=False, sharex=False, facecolor='white')
# plot the contours
nstd = 1.489
cov = np.cov(x, y)
vals, vecs = eigsorted(cov)
theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
w, h = 2 * nstd * np.sqrt(vals)
ell = Ellipse(xy=(np.mean(x), np.mean(y)),
              width=w, height=h,
              angle=theta, color='black')
ell.set_facecolor('none')
ax[0].add_artist(ell)

nstd = 2.4475
cov = np.cov(x, y)
vals, vecs = eigsorted(cov)
theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
w, h = 2 * nstd * np.sqrt(vals)
ell = Ellipse(xy=(np.mean(x), np.mean(y)),
              width=w, height=h,
              angle=theta, color='black')
ell.set_facecolor('none')
ax[0].add_artist(ell)
#####################################

ax[0].scatter(x, y, alpha=0.00)

# Set the x-axis and y-axis limits
ax[0].set_xlim(0, 0.075)  # Set x-axis limits from 0 to 6
ax[0].set_ylim(0.01, 0.06)  # Set y-axis limits from 0 to 6

# FSUGarnet, Gold2, DINOa,b,c, IUFSU, BigApple
# FSUGold2_L47, FSUGold2_L50, FSUGold2_L54, FSUGold2_L58, FSUGold2_L69, FSUGold2_L76, FSUGold2_L90, FSUGold2_L100, RMF022, RMF028, RMF032
# TAMUa, OMEG1, OMEG2
fch_fwk_Pb208 = np.array([0.0232,0.0422,0.0265,0.0303,0.0344,0.0233,0.0215,
                    0.0216,0.0242,0.0269,0.0290,0.0333,0.0353,0.0385,0.0403,0.0315,0.0421,0.0467,
                    0.0366,0.0359,0.0303,0.0200])

fch_fwk_Ca48 = np.array([0.0438,0.0565,0.0336,0.0349,0.0367,0.0439,0.0417,
                    0.0422,0.0442,0.0462,0.0477,0.0507,0.0520,0.0541,0.0553,0.0494,0.0566,0.0583,
                    0.0527,0.05079,0.0472,0.0400])

# Other models
ax[0].plot(fch_fwk_Pb208,fch_fwk_Ca48,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=11,linestyle='None')
ax[0].plot(0.02297,0.0437,marker='s',markerfacecolor='maroon',markeredgecolor='maroon',markersize=11) #FSUGarnet
ax[0].plot(0.0422,0.0565,marker='s',markerfacecolor='darkgoldenrod',markeredgecolor='darkgoldenrod',markersize=11) #FSUGold2
ax[0].plot(0.03839,0.05012,marker='*',markerfacecolor='purple',markeredgecolor='purple',markersize=23) #exp

# FSUtd
ax[0].plot(0.024,0.0336,marker='*',markerfacecolor='blue',markeredgecolor='black',markersize=23) #FSUtd-1
ax[0].plot(0.0211,0.0320,marker='*',markerfacecolor='red',markeredgecolor='black',markersize=23) #FSUtd-2
ax[0].plot(0.0186,0.0366,marker='*',markerfacecolor='green',markeredgecolor='black',markersize=23) #FSUtd-3
ax[0].plot(0.0342,0.0388,marker='*',markerfacecolor='orange',markeredgecolor='black',markersize=23) #FSU-exp

#ax[0].plot(0.0235,0.0336,marker='*',markerfacecolor='darkgoldenrod',markeredgecolor='black',markersize=18) #exp

dinoa_RM = np.loadtxt("DINOa_RM.txt")
garnet_RM = np.loadtxt("FSUGarnet_RM.txt")
gold_RM = np.loadtxt("gold_RM.txt")
#FSUTDa_RM = np.loadtxt("FSUTDa_RM.txt")
#FSUTDb_RM = np.loadtxt("FSUTDb_RM.txt")
FSUT_RM = np.loadtxt("FSUT_RM.txt")
FSUTDa_RM = np.loadtxt("FSU-TDa_xi_RM.txt")
FSUTDb_RM = np.loadtxt("FSU-TDb_xi_RM.txt")

ax[1].plot(dinoa_RM[:,3],dinoa_RM[:,4],color='black',lw=3)
ax[1].plot(FSUT_RM[:,3],FSUT_RM[:,4],color='green',lw=3)
ax[1].plot(FSUTDa_RM[:,3],FSUTDa_RM[:,4],color='blue',lw=3)
ax[1].plot(FSUTDb_RM[:,3],FSUTDb_RM[:,4],color='red',lw=3)
ax[1].plot(garnet_RM[:,3],garnet_RM[:,4],color='maroon',lw=3)
ax[1].plot(gold_RM[:,3],gold_RM[:,4],color='darkgoldenrod',lw=3)

nicer_68 = np.loadtxt("J0740_Riley21_68.txt")
nicer_95 = np.loadtxt("J0740_Riley21_95.txt")
riley_68 = np.loadtxt("J0030_Riley19_NICERonly_STPST_68.txt")
riley_95 = np.loadtxt("J0030_Riley19_NICERonly_STPST_95.txt")
J1231_68 = np.loadtxt("J1231_R21_contour_radius_mass_683.txt")
J1231_95 = np.loadtxt("J1231_R21_contour_radius_mass_954.txt")
J0437_68 = np.loadtxt("J0437_CST_PDT_3C50_BKG_AGN_smooth_3sigma_hiMN_lowXPSI_res_68.txt")
J0437_95 = np.loadtxt("J0437_CST_PDT_3C50_BKG_AGN_smooth_3sigma_hiMN_lowXPSI_res_95.txt")
ax[1].plot(nicer_68[:,0],nicer_68[:,1],color='black')
ax[1].plot(nicer_95[:,0],nicer_95[:,1],color='black')
ax[1].plot(riley_68[:,0],riley_68[:,1],color='black')
ax[1].plot(riley_95[:,0],riley_95[:,1],color='black')
ax[1].plot(J1231_68[:,0], J1231_68[:,1], color='black')
ax[1].plot(J1231_95[:,0], J1231_95[:,1], color='black')
ax[1].plot(J0437_68[:,0], J0437_68[:,1], color='black')
ax[1].plot(J0437_95[:,0], J0437_95[:,1], color='black')

ax[1].fill(nicer_68[:,0],nicer_68[:,1], color='indianred', alpha=0.5)
ax[1].fill(nicer_95[:,0],nicer_95[:,1], color='lightcoral', alpha=0.1)
ax[1].fill(riley_68[:,0],riley_68[:,1], color='olivedrab', alpha=0.5)
ax[1].fill(riley_95[:,0],riley_95[:,1], color='yellowgreen', alpha=0.1)
ax[1].fill(J1231_68[:,0],J1231_68[:,1], color='darkslategrey', alpha=0.5)
ax[1].fill(J1231_95[:,0],J1231_95[:,1], color='teal', alpha=0.2)
ax[1].fill(J0437_68[:,0],J0437_68[:,1], color='rebeccapurple', alpha=0.5)
ax[1].fill(J0437_95[:,0],J0437_95[:,1], color='blueviolet', alpha=0.2)

ax[0].set_xlabel(r'${\rm F}_{\rm ch} - {\rm F}_{\rm wk}$ ($^{208}$Pb)',size=25)
ax[0].set_ylabel(r'${\rm F}_{\rm ch} - {\rm F}_{\rm wk}$ ($^{48}$Ca)',size=25)

ax[1].set_xlabel('Radius (km)',size=25)
ax[1].set_ylabel(r'Mass ($M/M_{\odot}$)',size=25)

# Set the x-axis and y-axis limits
ax[1].set_xlim(11, 19)  # Set x-axis limits from 0 to 6

ax[0].text(0.024,0.024,'67\%',fontsize=20)
ax[0].text(0.014,0.021,'95\%',fontsize=20)
ax[0].text(0.008,0.045,'FSUGarnet',fontsize=22)
ax[0].text(0.027,0.057,'FSUGold2',fontsize=22)
ax[0].text(0.016,0.05,'FSU-RBM',fontsize=22)

ax[0].text(0.028,0.032,'a',fontsize=20)
ax[0].text(0.031,0.033,'b',fontsize=20)
ax[0].text(0.035,0.0345,'c',fontsize=20)

ax[1].text(15.8,2.3,r'(Upper 90 $\%) \Lambda_{1.4}$ = 580',fontsize=20)
plt.legend([r'DINOa $(\Lambda_{1.4} = 1323.6)$',r'FSU-TD0  $(\Lambda_{1.4} = 616.7$)',r'FSU-TD1 + $\xi$ $(\Lambda_{1.4} = 846.4$)',r'FSU-TD2 + $\xi$  $(\Lambda_{1.4} = 735.4$)',r'FSUGarnet  $(\Lambda_{1.4} = 529.1$)',r'FSUGold2  $(\Lambda_{1.4} = 925.4$)'],fontsize=16,loc=[0.50,0.24])

plt.tight_layout()
#plt.savefig('Figure21_defense',dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rc('axes', unicode_minus=False)
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

chargeffCa48_FSUTDa = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_FSUTDa.txt")
chargeffCa48_FSUTDb = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_FSUTDb.txt")
chargeffCa48_FSUT = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Ca48_FSUT.txt")
chargeffCa48_gar = np.loadtxt("q_transfer_Fch,Fwk,wkskin,ca48,gar.txt")
chargeffCa48_gold = np.loadtxt("q_transfer_Fch,Fwk,wkskin,ca48,gold.txt")
chargeffPb_gar = np.loadtxt("q_transfer_Fch,Fwk,wkskin,pb208,gar.txt")
chargeffPb_gold = np.loadtxt("q_transfer_Fch,Fwk,wkskin,pb208,gold.txt")
chargeffPb_FSUTDa = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb_FSUTDa.txt")
chargeffPb_FSUTDb = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb_FSUTDb.txt")
chargeffPb_FSUT = np.loadtxt("q_transfer_Fch,Fwk,wkskin,Pb_FSUT.txt")

chargeffCa48_exp = np.loadtxt("FBFoFa48Ca.txt")
chargeffPb_exp = np.loadtxt("FBFoFa208Pb.txt")

# Adjust start and end of EOS data
l = 300
m = 300

fig, axs = plt.subplots(1, 2,figsize=(15,6),sharey=False, sharex=False, facecolor='white')

q = chargeffCa48_FSUT[:m,0]/1.25
exp = chargeffCa48_FSUT[:m,3]
axs[0].plot(q, exp, color='green',ls='solid',lw=3)

q = chargeffCa48_FSUTDa[:m,0]/1.25
exp = chargeffCa48_FSUTDa[:m,3]
axs[0].plot(q, exp, color='blue',ls='solid',lw=3)

q = chargeffCa48_FSUTDb[:m,0]/1.25
exp = chargeffCa48_FSUTDb[:m,3]
axs[0].plot(q, exp, color='red',ls='solid',lw=3)

q = chargeffCa48_gold[:m,0]/1.25
exp = chargeffCa48_gold[:m,3]
axs[0].plot(q, exp, color='darkgoldenrod',ls='solid',lw=3)

q = chargeffCa48_gar[:m,0]/1.25
exp = chargeffCa48_gar[:m,3]
axs[0].plot(q, exp, color='maroon',ls='solid',lw=3)

q = chargeffPb_FSUT[:l,0]/1.25
exp = chargeffPb_FSUT[:l,3]
axs[1].plot(q, exp, color='green',ls='solid',lw=3)

q = chargeffPb_FSUTDa[:l,0]/1.25
exp = chargeffPb_FSUTDa[:l,3]
axs[1].plot(q, exp, color='blue',ls='solid',lw=3)

q = chargeffPb_FSUTDb[:l,0]/1.25
exp = chargeffPb_FSUTDb[:l,3]
axs[1].plot(q, exp, color='red',ls='solid',lw=3)

q = chargeffPb_gold[:m,0]/1.25
exp = chargeffPb_gold[:m,3]
axs[1].plot(q, exp, color='darkgoldenrod',ls='solid',lw=3)

q = chargeffPb_gar[:m,0]/1.25
exp = chargeffPb_gar[:m,3]
axs[1].plot(q, exp, color='maroon',ls='solid',lw=3)

axs[0].errorbar(0.8733,0.0277,yerr=[[0.0055],[0.0055]],capsize=5, color='black')
axs[1].errorbar(0.3977,0.041,yerr=[[0.013],[0.013]],capsize=5, color='black')
#axs[0].axvline(0.8733,ls='dashed',ymax=0.87,color='black')
#axs[1].axvline(0.3977,ls='dashed',ymax=0.95,color='black')
axs[0].plot(0.8733,0.0277,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=8) #crex
axs[1].plot(0.3977,0.041,marker='s',markerfacecolor='black',markeredgecolor='black',markersize=8) #prex

axs[1].set_ylabel(r'$\rm F_{ch} - F_{wk}$ ($^{208}$Pb)',size=20)
axs[0].set_ylabel(r'$\rm F_{ch} - F_{wk}$ ($^{48}$Ca)',size=20)

axs[1].set_xlabel(r'q (fm$^{-1})$',size=20)
axs[0].set_xlabel(r'q (fm$^{-1})$',size=20)

plt.legend(['FSU-TD0','FSU-TD1','FSU-TD2','FSUGold2','FSUGarnet'],fontsize=18,loc='upper right')
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.tight_layout()

plt.savefig('Figure22',dpi=500)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

data = np.loadtxt("XEFTNM.txt")
FSUTDa_PNM = np.loadtxt("FSU-TDa_PNM.txt")
FSUTDb_PNM = np.loadtxt("FSU-TDb_PNM.txt")
FSUT_PNM = np.loadtxt("FSU-T_PNM.txt")

FSUTDa_xi_PNM = np.loadtxt("FSU-TDa_xi_PNM.txt")
FSUTDb_xi_PNM = np.loadtxt("FSU-TDb_xi_PNM.txt")
FSUT_xi_PNM = np.loadtxt("FSU-T_xi_PNM.txt")

# Adjust end of XEFT data
n = 35

# Adjust start and end of EOS data
l = 90
m = 180

x = data[0:n,0]
y = data[0:n,1]
error1 = data[0:n,2]

# plot XEFT data and FSU PNM EOS
plt.figure(figsize=(8,8))
plt.plot(x,y)

plt.plot(FSUT_PNM[l:m,0],FSUT_PNM[l:m,1],color='green',linewidth=3)
plt.plot(FSUTDa_PNM[l:m,0],FSUTDa_PNM[l:m,1],color='blue',linewidth=3)
plt.plot(FSUTDb_PNM[l:m,0],FSUTDb_PNM[l:m,1],color='red',linewidth=3)

plt.plot(FSUTDa_xi_PNM[l:m,0],FSUTDa_xi_PNM[l:m,1],color='blue',linewidth=3,linestyle='dashed')
plt.plot(FSUTDb_xi_PNM[l:m,0],FSUTDb_xi_PNM[l:m,1],color='red',linewidth=3,linestyle='dashed')
#plt.plot(FSUT_xi_PNM[l:m,0],FSUT_xi_PNM[l:m,1],color='green',linewidth=2,linestyle='dashed')

plt.fill_between(x, y-error1, y+error1, alpha=0.3)
plt.legend(['Chiral EFT','FSU-TD0','FSU-TD1','FSU-TD2'],fontsize=21)
plt.xlabel(r'$\rho$ ($\rm fm^{-3}$)')
plt.ylabel('E/N (MeV)')
plt.rc('axes', labelsize=27)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=27)    # fontsize of the tick labels
plt.rc('ytick', labelsize=27)    # fontsize of the tick labels
plt.tight_layout()
plt.savefig('Figure23',transparent=False,facecolor='white',dpi=500)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

fig, ax = plt.subplots(1, 1,figsize=(9,9),sharey=False, sharex=False, facecolor='white')

FSUTDa_RM = np.loadtxt("FSUTDa_RM.txt")
FSUTDb_RM = np.loadtxt("FSUTDb_RM.txt")
FSUT_RM = np.loadtxt("FSUT_RM.txt")

FSUTDa_xi_RM = np.loadtxt("FSU-TDa_xi_RM.txt")
FSUTDb_xi_RM = np.loadtxt("FSU-TDb_xi_RM.txt")

ax.plot(FSUT_RM[:,3],FSUT_RM[:,4],color='green',linewidth=3)
ax.plot(FSUTDa_RM[:,3],FSUTDa_RM[:,4],color='blue',linewidth=3)
ax.plot(FSUTDb_RM[:,3],FSUTDb_RM[:,4],color='red',linewidth=3)

ax.plot(FSUTDa_xi_RM[:,3],FSUTDa_xi_RM[:,4],color='blue',linestyle='dashed',linewidth=3)
ax.plot(FSUTDb_xi_RM[:,3],FSUTDb_xi_RM[:,4],color='red',linestyle='dashed',linewidth=3)

nicer_68 = np.loadtxt("J0740_Riley21_68.txt")
nicer_95 = np.loadtxt("J0740_Riley21_95.txt")
riley_68 = np.loadtxt("J0030_Riley19_NICERonly_STPST_68.txt")
riley_95 = np.loadtxt("J0030_Riley19_NICERonly_STPST_95.txt")
J1231_68 = np.loadtxt("J1231_R21_contour_radius_mass_683.txt")
J1231_95 = np.loadtxt("J1231_R21_contour_radius_mass_954.txt")
J0437_68 = np.loadtxt("J0437_CST_PDT_3C50_BKG_AGN_smooth_3sigma_hiMN_lowXPSI_res_68.txt")
J0437_95 = np.loadtxt("J0437_CST_PDT_3C50_BKG_AGN_smooth_3sigma_hiMN_lowXPSI_res_95.txt")
ax.plot(nicer_68[:,0],nicer_68[:,1],color='black')
ax.plot(nicer_95[:,0],nicer_95[:,1],color='black')
ax.plot(riley_68[:,0],riley_68[:,1],color='black')
ax.plot(riley_95[:,0],riley_95[:,1],color='black')
ax.plot(J1231_68[:,0], J1231_68[:,1], color='black')
ax.plot(J1231_95[:,0], J1231_95[:,1], color='black')
ax.plot(J0437_68[:,0], J0437_68[:,1], color='black')
ax.plot(J0437_95[:,0], J0437_95[:,1], color='black')

ax.fill(nicer_68[:,0],nicer_68[:,1], color='skyblue', alpha=0.5)
ax.fill(nicer_95[:,0],nicer_95[:,1], color='blue', alpha=0.1)
ax.fill(riley_68[:,0],riley_68[:,1], color='skyblue', alpha=0.5)
ax.fill(riley_95[:,0],riley_95[:,1], color='blue', alpha=0.1)
ax.fill(J1231_68[:,0],J1231_68[:,1], color='darkslategrey', alpha=0.5)
ax.fill(J1231_95[:,0],J1231_95[:,1], color='teal', alpha=0.2)
ax.fill(J0437_68[:,0],J0437_68[:,1], color='rebeccapurple', alpha=0.5)
ax.fill(J0437_95[:,0],J0437_95[:,1], color='blueviolet', alpha=0.2)

ax.set_xlabel('Radius (km)',size=25)
ax.set_ylabel(r'Mass ($\rm M/M_{\odot}$)',size=25)

ax.set_xlim(11, 19)  # Set x-axis limits from 0 to 6

matplotlib.rc('xtick', labelsize=23) 
matplotlib.rc('ytick', labelsize=23)
plt.legend([r'FSU-TD0  $(\Lambda_{1.4} = 616.7$)',r'FSU-TD1 $(\Lambda_{1.4} = 1072.3$)',r'FSU-TD2  $(\Lambda_{1.4} = 822.8$)',r'FSU-TD1+ $\xi$ $(\Lambda_{1.4} = 846.4$)',r'FSU-TD2 + $\xi$  $(\Lambda_{1.4} = 735.4$)'],fontsize=18,loc=[0.47,0.2])

plt.tight_layout()
plt.savefig('Figure24',dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
    'font.serif': ['Computer Modern'],
    'font.size': 20,
    'axes.titlesize': 14,
    'axes.labelsize': 21,
    'xtick.labelsize': 21,
    'ytick.labelsize': 21,
    'legend.fontsize': 16,
    'text.latex.preamble': r'\usepackage{bm}',
})

DINOa_Symm = np.loadtxt("DINOa_Symm.txt")
FSUTDb_Symm = np.loadtxt("FSU-TDb_Symm.txt")
FSUT_Symm = np.loadtxt("FSU-T_Symm.txt")

# Adjust start and end of EOS data
l = 0
m = 170

# plot XEFT data and FSU PNM EOS
plt.figure(figsize=(8,8))

plt.plot(DINOa_Symm[l:m,0],DINOa_Symm[l:m,2],color='blue',linewidth=3)
plt.plot(FSUT_Symm[l:m,0],FSUT_Symm[l:m,2],color='green',linewidth=3)
plt.plot(FSUTDb_Symm[l:m,0],FSUTDb_Symm[l:m,2],color='red',linewidth=3)
plt.legend(['DINOa','FSU-TD0','FSU-TD2'],fontsize=21)

plt.plot(DINOa_Symm[l:m,0],DINOa_Symm[l:m,1],color='blue',linewidth=3,linestyle='dashed')
plt.plot(FSUT_Symm[l:m,0],FSUT_Symm[l:m,1],color='green',linewidth=3,linestyle='dashed')
plt.plot(FSUTDb_Symm[l:m,0],FSUTDb_Symm[l:m,1],color='red',linewidth=3,linestyle='dashed')

plt.xlabel(r'$\rho$ ($\rm fm^{-3}$)')
plt.ylabel('Symmetry Energy (MeV)')
plt.rc('axes', labelsize=30)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=22)    # fontsize of the tick labels
plt.rc('ytick', labelsize=22)    # fontsize of the tick labels
plt.tight_layout()

plt.savefig('Figure25',dpi=500)
